# %% [markdown]
# # Homework 5

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import time

from keras.datasets import cifar10
from keras.utils import to_categorical
from tensorflow.keras.layers import Layer
from tensorflow.keras import Model
from keras.optimizers import SGD

# %% [markdown]
# # Load data

# %%
# Load the cifar10 dataset simply works with the function load_data().
(train_inputs, train_labels), (test_inputs, test_labels) = cifar10.load_data()

# %%
print(train_inputs.shape)
print(train_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %% [markdown]
# #Print some examples from the datasets

# %%
# Names of labels
labels = ['airplane', 
          'automobile',
          'bird',
          'cat',
          'deer',
          'dog',
          'frog',
          'horse',
          'ship',
          'truck']


# Plot 100 examples
_, ax = plt.subplots(10, 10, figsize=(15,15))
for i, img in enumerate(train_inputs[49899:49999]):
  ax[int(i/10), i%10].imshow(img)
  ax[int(i/10), i%10].set_title(str(labels[train_labels[i+49899][0]]))
  ax[int(i/10), i%10].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Augmentation
#
# Augmenting data like this (not generating 'on the fly') but saving them in the data arrays limits data augmentation to approximately 200.000 images as this is where for Google Colab all resources are used.

# %%
# Initialize data generator:
# Changes in rotation, brightness, shifting in width and height, and flipping horizontally
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    rotation_range=30,
    brightness_range=(0.3,0.7),
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)

# Create augmented data
train_generator = datagen.flow(train_inputs, train_labels, batch_size=100)

# Create new data arrays - and add augmented images
train_inputs_aug = np.zeros((90000, 32, 32, 3))
train_labels_aug = np.zeros((90000, 1))
train_inputs_aug[:50000,:,:,:] = train_inputs / 255.
train_labels_aug[:50000,:] = train_labels

# Add augmented images
pos = 50000
for i, (image, label) in enumerate(train_generator):

  # Stop after creating 40000 images
  if i >= 400:
    break
  
  train_inputs_aug[pos:pos+100,:,:,:] = image
  train_labels_aug[pos:pos+100] = label

  # Next position
  pos = pos+100

# %% [markdown]
# # Print some info on augmented data and show some examples

# %%
# Show some info and example images
print('Training - image shape: %s, label shape: %s' % (train_inputs_aug.shape, train_labels_aug.shape))
print('Testing - image shape: %s, label shape: %s' % (test_inputs.shape, test_labels.shape))

# Some augmented training images and their labels
_, ax = plt.subplots(10, 10, figsize=(15,15))
for i, img in enumerate(train_inputs_aug[79899:79999]):
  ax[int(i/10), i%10].imshow(img)
  ax[int(i/10), i%10].set_title(str(labels[int(train_labels_aug[i+79899])]))
  ax[int(i/10), i%10].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Training - image shape: (90000, 32, 32, 3), label shape: (90000, 1)
# Testing - image shape: (10000, 32, 32, 3), label shape: (10000, 1)

# %% [markdown]
# # Including or excluding augmented data and first data preprocessing
#
# For the final version, we did not need the augmented data. So here, one can find the option to either use also the augmented data or not.

# %%
# change dtype
include_augmented_data  = False

if include_augmented_data:
  train_inputs = train_inputs_aug.astype(np.float32)
  train_labels = train_labels_aug.astype(np.uint8)
else:
  train_inputs = train_inputs.astype(np.float32)
  train_labels = train_labels.astype(np.uint8)

test_inputs = test_inputs.astype(np.float32)
test_labels = test_labels.astype(np.uint8)

print(train_inputs.dtype)
print(train_labels.dtype)

print(test_inputs.dtype)
print(test_labels.dtype)
# Out:
# float32
# uint8
# float32
# uint8

# %% [markdown]
# #Preprocessing Pipeline

# %%
# Preprocess training data
train_inputs_prep = tf.data.Dataset.from_tensor_slices(train_inputs)
train_labels_prep = tf.data.Dataset.from_tensor_slices(train_labels)

# Normalize images and one hot encode the labels
train_inputs_prep = train_inputs_prep.map(lambda x: tf.image.per_image_standardization(x/255))
train_labels_prep = train_labels_prep.map(lambda x: tf.reshape(tf.one_hot(x, 10), (-1,)))

# Batching, shuffling and prefetching
train_data = tf.data.Dataset.zip((train_inputs_prep, train_labels_prep))
train_data = train_data.shuffle(buffer_size=10000)
train_data = train_data.batch(32, drop_remainder=True)
train_data = train_data.prefetch(buffer_size=32)

# Preprocess testing data
test_inputs_prep = tf.data.Dataset.from_tensor_slices(test_inputs)
test_labels_prep = tf.data.Dataset.from_tensor_slices(test_labels)

# Normalize images and one hot encode the labels
test_inputs_prep = test_inputs_prep.map(lambda x : tf.image.per_image_standardization(x/255))
test_labels_prep = test_labels_prep.map(lambda x: tf.reshape(tf.one_hot(x, 10), (-1,)))

# Batching, shuffling and prefetching
test_data = tf.data.Dataset.zip((test_inputs_prep, test_labels_prep))
test_data = test_data.shuffle(buffer_size=10000)
test_data = test_data.batch(32, drop_remainder=True)
test_data = test_data.prefetch(buffer_size=32)

# %% [markdown]
# # Define the Model
#
# Our model consists of four big blocks that each consist of a Convolutional layer, Batch Normalization, again a Convolutional layer, Max Pooling an finally a Dropout layer. The number of filters for the Convolutional layers increase (double) for each block. After those four big blocks follows a Global Average Pooling layer and finally the output layer.

# %%
from tensorflow.keras import Model
# activation functions
RELU = tf.keras.activations.relu
SOFTMAX = tf.keras.activations.softmax

class Model(Model):

  def __init__(self):
    """
    """
    super(Model, self).__init__()

    # First conv block 
    self.conv_first_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=(4,4), activation=None, padding='same', input_shape=(32,32,3))
    self.batch_norm_first_1 = tf.keras.layers.BatchNormalization()
    self.conv_second_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=(4,4), activation=RELU, padding='same')
    self.max_pool_1 = tf.keras.layers.MaxPool2D((2,2))
    self.dropout_1 = tf.keras.layers.Dropout(0.25)

    # Second conv block
    self.conv_first_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation=None, padding='same')
    self.batch_norm_first_2 = tf.keras.layers.BatchNormalization()
    self.conv_second_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation=RELU, padding='same')
    self.max_pool_2 = tf.keras.layers.MaxPool2D((2,2))
    self.dropout_2 = tf.keras.layers.Dropout(0.25)

    # Third conv block
    self.conv_first_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation=None, padding='same')
    self.batch_norm_first_3 = tf.keras.layers.BatchNormalization()
    self.conv_second_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation=RELU, padding='same')
    self.max_pool_3 = tf.keras.layers.MaxPool2D((2,2))
    self.dropout_3 = tf.keras.layers.Dropout(0.25)

    # 4.  conv block
    self.conv_first_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), activation=None, padding='same')
    self.batch_norm_first_4 = tf.keras.layers.BatchNormalization()
    self.conv_second_4 = tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), activation=RELU, padding='same')
    self.max_pool_4 = tf.keras.layers.MaxPool2D((2,2))
    self.dropout_4 = tf.keras.layers.Dropout(0.25)
    
    self.global_pool = tf.keras.layers.GlobalAveragePooling2D()
    self.dropout_5 = tf.keras.layers.Dropout(0.3)

    # Output
    self.output_layer = tf.keras.layers.Dense(10, activation=SOFTMAX)


  @tf.function
  def call(self, x, training=True):
    """
    FORWARD STEP
    forward input x through the whole network
    """

    # First conv block 
    x = self.conv_first_1(x)
    x = self.batch_norm_first_1(x, training)
    x = self.conv_second_1(x)
    x = self.max_pool_1(x)
    if training:
      x = self.dropout_1(x)

    # Second conv block
    x = self.conv_first_2(x)
    x = self.batch_norm_first_2(x, training)
    x = self.conv_second_2(x)
    x = self.max_pool_2(x)
    if training:
      x = self.dropout_2(x)

    # Third conv block
    x = self.conv_first_3(x)
    x = self.batch_norm_first_3(x, training)
    x = self.conv_second_3(x)
    x = self.max_pool_3(x)
    if training:
      x = self.dropout_3(x)

    # 4. conv block
    x = self.conv_first_4(x)
    x = self.batch_norm_first_4(x, training)
    x = self.conv_second_4(x)
    x = self.max_pool_4(x)
    if training:
      x = self.dropout_4(x)
    
    x = self.global_pool(x)

    if training:
      x = self.dropout_5(x)

    # Output
    x = self.output_layer(x)

    return x

# %%
def train_step(model, input, target, loss_function, optimizer):
  """
  performs one training step
  model :         our model
  input :         the input that is fed into the model
  target :        true label of input
  loss_function : our loss function
  optimizer :     our optimizer
  """
  with tf.GradientTape() as tape:
    prediction = model(input)
    loss = loss_function(target, prediction)
    accuracy = np.mean(np.argmax(target, axis=1) == np.argmax(prediction, axis=1))
    gradients = tape.gradient(loss, model.trainable_variables)

  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

  return np.mean(loss), accuracy 


def test(model, test_data, loss_function):
  """
  test model over complete test data set
  model :         our model
  test_data :     our test data
  loss_function : our loss function
  """

  test_accuracy_aggregator = []
  test_loss_aggregator = []

  # iterate over the test data set and predict each label
  # also calculate loss and accuracy 
  for (input, target) in test_data:

    # For testing, leave out the dropout and Batch Normalization layers by setting training=False
    prediction = model(input, training=False)
    loss = cross_entropy_loss(target, prediction)
    accuracy = np.sum(np.argmax(target, axis=1) == np.argmax(prediction, axis=1)) / target.shape[0]
    test_accuracy_aggregator.append(accuracy)
    test_loss_aggregator.append(loss)

  test_loss = np.mean(test_loss_aggregator)
  test_accuracy = np.mean(test_accuracy_aggregator)

  return test_loss, test_accuracy

# %% [markdown]
# # Set hyperparameters and initialize the model

# %%
tf.keras.backend.clear_session()

# Hyperparameters
num_epochs = 100
learning_rate = 0.0001
running_average_factor = 0.95

model = Model()

cross_entropy_loss = tf.keras.losses.categorical_crossentropy

optimizer = tf.keras.optimizers.Adam(learning_rate)

# Initialize lists for later visualization.
train_losses = []
train_accuracies = []

test_losses = []
test_accuracies = []

# Testing once before we begin
#test_loss, test_accuracy = test(model, test_data, cross_entropy_loss)
#test_losses.append(test_loss)
#test_accuracies.append(test_accuracy)

#check how model performs on train data once before we begin
#train_loss, train_accuracy = test(model, train_data, cross_entropy_loss)
#train_losses.append(train_loss)
#train_accuracies.append(train_accuracy)

# %% [markdown]
# # Training the model

# %%
# We train for num_epochs epochs.
for epoch in range(num_epochs):
  
  # Track epoch and time while code runs
  start = time.time()
  print('Epoch: __ ' + str(epoch+1))
  """  
  if epoch < 25: 
    learning_rate = 1.05 * learning_rate
    optimizer = tf.keras.optimizers.Adam(learning_rate)
  else:
    learning_rate = 0.999 * learning_rate 
    optimizer = tf.keras.optimizers.Adam(learning_rate)
  """

  train_data = train_data.shuffle(buffer_size=256)
  test_data = test_data.shuffle(buffer_size=256)

  #training (and checking in with training)
  running_average_loss = 0
  running_average_accuracy = 0

  for (input, target) in train_data:
      train_loss, train_accuracy = train_step(model, input, target, cross_entropy_loss, optimizer)
      running_average_loss = running_average_factor * running_average_loss  + (1 - running_average_factor) * train_loss
      running_average_accuracy = running_average_factor * running_average_accuracy  + (1 - running_average_factor) * train_accuracy

  train_losses.append(running_average_loss)
  train_accuracies.append(running_average_accuracy)

  #testing
  test_loss, test_accuracy = test(model, test_data, cross_entropy_loss)
  test_losses.append(test_loss)
  test_accuracies.append(test_accuracy)

  duration = time.time() - start

  # Measure time required for each epoch + show loss and accuracy progress
  print('... finished after %s seconds --- Train loss: %s - Train accuracy: %s --- Test loss: %s - Test accuracy: %s ' % (round(duration, 2), round(running_average_loss, 4), round(running_average_accuracy, 4), round(test_loss, 4), round(test_accuracy, 4)))
# Out:
# Epoch: __ 1
# ... finished after 48.39 seconds --- Train loss: 1.3589 - Train accuracy: 0.5243 --- Test loss: 1.5801 - Test accuracy: 0.4682
# Epoch: __ 2
# ... finished after 46.91 seconds --- Train loss: 1.1373 - Train accuracy: 0.5785 --- Test loss: 1.1294 - Test accuracy: 0.6028
# Epoch: __ 3
# ... finished after 47.17 seconds --- Train loss: 0.9551 - Train accuracy: 0.6506 --- Test loss: 0.9966 - Test accuracy: 0.6502
# Epoch: __ 4
# ... finished after 48.13 seconds --- Train loss: 0.8917 - Train accuracy: 0.6817 --- Test loss: 0.874 - Test accuracy: 0.6984
# Epoch: __ 5
# ... finished after 48.11 seconds --- Train loss: 0.822 - Train accuracy: 0.7097 --- Test loss: 0.7831 - Test accuracy: 0.7278
# Epoch: __ 6
# ... finished after 48.16 seconds --- Train loss: 0.8223 - Train accuracy: 0.7191 --- Test loss: 0.7443 - Test accuracy: 0.74
# Epoch: __ 7
# ... finished after 48.39 seconds --- Train loss: 0.7507 - Train accuracy: 0.7473 --- Test loss: 0.7171 - Test accuracy: 0.7501
# Epoch: __ 8
# ... finished after 48.06 seconds --- Train loss: 0.6952 - Train accuracy: 0.7631 --- Test loss: 0.6971 - Test accuracy: 0.7564
# Epoch: __ 9
# ... finished after 47.9 seconds --- Train loss: 0.66 - Train accuracy: 0.7741 --- Test loss: 0.6591 - Test accuracy: 0.772
# Epoch: __ 10
# ... finished after 48.53 seconds --- Train loss: 0.6425 - Train accuracy: 0.7869 --- Test loss: 0.6173 - Test accuracy: 0.7872
# Epoch: __ 11
# ... finished after 48.02 seconds --- Train loss: 0.6268 - Train accuracy: 0.7844 --- Test loss: 0.6182 - Test accuracy: 0.7838
# Epoch: __ 12
# ... finished after 48.35 seconds --- Train loss: 0.5904 - Train accuracy: 0.7903 --- Test loss: 0.5615 - Test accuracy: 0.8039
# Epoch: __ 13
# ... finished after 48.24 seconds --- Train loss: 0.5777 - Train accuracy: 0.8035 --- Test loss: 0.5489 - Test accuracy: 0.8102
# Epoch: __ 14
# ... finished after 48.14 seconds --- Train loss: 0.6234 - Train accuracy: 0.777 --- Test loss: 0.5299 - Test accuracy: 0.8141
# Epoch: __ 15
# ... finished after 48.44 seconds --- Train loss: 0.6079 - Train accuracy: 0.7994 --- Test loss: 0.528 - Test accuracy: 0.8194
# Epoch: __ 16
# ... finished after 48.35 seconds --- Train loss: 0.5421 - Train accuracy: 0.8053 --- Test loss: 0.5431 - Test accuracy: 0.8146
# Epoch: __ 17
# ... finished after 48.45 seconds --- Train loss: 0.519 - Train accuracy: 0.8258 --- Test loss: 0.5111 - Test accuracy: 0.8243
# Epoch: __ 18
# ... finished after 48.21 seconds --- Train loss: 0.5178 - Train accuracy: 0.8131 --- Test loss: 0.5464 - Test accuracy: 0.8156
# Epoch: __ 19
# ... finished after 48.21 seconds --- Train loss: 0.5226 - Train accuracy: 0.8188 --- Test loss: 0.4895 - Test accuracy: 0.8321
# Epoch: __ 20
# ... finished after 48.5 seconds --- Train loss: 0.5036 - Train accuracy: 0.8233 --- Test loss: 0.5032 - Test accuracy: 0.829
# Epoch: __ 21
# ... finished after 48.63 seconds --- Train loss: 0.457 - Train accuracy: 0.8502 --- Test loss: 0.5123 - Test accuracy: 0.8277
# Epoch: __ 22
# ... finished after 48.65 seconds --- Train loss: 0.4986 - Train accuracy: 0.8413 --- Test loss: 0.5005 - Test accuracy: 0.8294
# Epoch: __ 23
# ... finished after 48.59 seconds --- Train loss: 0.4974 - Train accuracy: 0.8321 --- Test loss: 0.4731 - Test accuracy: 0.8415
# Epoch: __ 24
# ... finished after 48.36 seconds --- Train loss: 0.4425 - Train accuracy: 0.8465 --- Test loss: 0.509 - Test accuracy: 0.8277
# Epoch: __ 25
# ... finished after 48.88 seconds --- Train loss: 0.4805 - Train accuracy: 0.8491 --- Test loss: 0.4663 - Test accuracy: 0.8398
# Epoch: __ 26
# ... finished after 48.53 seconds --- Train loss: 0.4189 - Train accuracy: 0.863 --- Test loss: 0.4671 - Test accuracy: 0.841
# Epoch: __ 27
# ... finished after 48.52 seconds --- Train loss: 0.384 - Train accuracy: 0.8665 --- Test loss: 0.4649 - Test accuracy: 0.8453
# Epoch: __ 28
# ... finished after 48.62 seconds --- Train loss: 0.39 - Train accuracy: 0.8674 --- Test loss: 0.4811 - Test accuracy: 0.8363
# Epoch: __ 29
# ... finished after 48.76 seconds --- Train loss: 0.4122 - Train accuracy: 0.8572 --- Test loss: 0.4609 - Test accuracy: 0.8417
# Epoch: __ 30
# ... finished after 48.63 seconds --- Train loss: 0.3833 - Train accuracy: 0.878 --- Test loss: 0.4764 - Test accuracy: 0.8383
# Epoch: __ 31
# ... finished after 48.67 seconds --- Train loss: 0.3606 - Train accuracy: 0.8725 --- Test loss: 0.4492 - Test accuracy: 0.8489
# Epoch: __ 32
# ... finished after 48.34 seconds --- Train loss: 0.4231 - Train accuracy: 0.8328 --- Test loss: 0.4513 - Test accuracy: 0.848
# Epoch: __ 33
# ... finished after 48.42 seconds --- Train loss: 0.3754 - Train accuracy: 0.8687 --- Test loss: 0.4554 - Test accuracy: 0.8452
# Epoch: __ 34
# ... finished after 48.53 seconds --- Train loss: 0.372 - Train accuracy: 0.8663 --- Test loss: 0.4416 - Test accuracy: 0.8514
# Epoch: __ 35
# ... finished after 48.39 seconds --- Train loss: 0.3464 - Train accuracy: 0.877 --- Test loss: 0.4475 - Test accuracy: 0.8461
# Epoch: __ 36
# ... finished after 48.78 seconds --- Train loss: 0.3555 - Train accuracy: 0.8738 --- Test loss: 0.451 - Test accuracy: 0.8477
# Epoch: __ 37
# ... finished after 48.85 seconds --- Train loss: 0.3587 - Train accuracy: 0.8674 --- Test loss: 0.4515 - Test accuracy: 0.8496
# Epoch: __ 38
# ... finished after 48.52 seconds --- Train loss: 0.3584 - Train accuracy: 0.8671 --- Test loss: 0.4472 - Test accuracy: 0.8504
# Epoch: __ 39
# ... finished after 48.68 seconds --- Train loss: 0.3346 - Train accuracy: 0.8817 --- Test loss: 0.4484 - Test accuracy: 0.8494
# Epoch: __ 40
# ... finished after 48.28 seconds --- Train loss: 0.3097 - Train accuracy: 0.8954 --- Test loss: 0.4442 - Test accuracy: 0.8502
# Epoch: __ 41
# ... finished after 48.49 seconds --- Train loss: 0.3659 - Train accuracy: 0.8757 --- Test loss: 0.4329 - Test accuracy: 0.8524
# Epoch: __ 42
# ... finished after 48.79 seconds --- Train loss: 0.3225 - Train accuracy: 0.886 --- Test loss: 0.4289 - Test accuracy: 0.857
# Epoch: __ 43
# ... finished after 48.25 seconds --- Train loss: 0.3158 - Train accuracy: 0.8966 --- Test loss: 0.4426 - Test accuracy: 0.8526
# Epoch: __ 44
# ... finished after 48.52 seconds --- Train loss: 0.3526 - Train accuracy: 0.8818 --- Test loss: 0.4342 - Test accuracy: 0.8564
# Epoch: __ 45
# ... finished after 48.24 seconds --- Train loss: 0.348 - Train accuracy: 0.8766 --- Test loss: 0.4249 - Test accuracy: 0.8577
# Epoch: __ 46
# ... finished after 48.15 seconds --- Train loss: 0.3564 - Train accuracy: 0.8744 --- Test loss: 0.4545 - Test accuracy: 0.8503
# Epoch: __ 47
# ... finished after 48.14 seconds --- Train loss: 0.3188 - Train accuracy: 0.886 --- Test loss: 0.4451 - Test accuracy: 0.8543
# Epoch: __ 48
# ... finished after 48.01 seconds --- Train loss: 0.2951 - Train accuracy: 0.8979 --- Test loss: 0.4322 - Test accuracy: 0.8568
# Epoch: __ 49
# ... finished after 48.31 seconds --- Train loss: 0.3144 - Train accuracy: 0.8864 --- Test loss: 0.4283 - Test accuracy: 0.8599
# Epoch: __ 50
# ... finished after 48.34 seconds --- Train loss: 0.308 - Train accuracy: 0.8865 --- Test loss: 0.4348 - Test accuracy: 0.8547
# Epoch: __ 51
# ... finished after 47.99 seconds --- Train loss: 0.269 - Train accuracy: 0.9042 --- Test loss: 0.4206 - Test accuracy: 0.8623
# Epoch: __ 52
# ... finished after 48.12 seconds --- Train loss: 0.3255 - Train accuracy: 0.8828 --- Test loss: 0.4854 - Test accuracy: 0.8461
# Epoch: __ 53
# ... finished after 48.12 seconds --- Train loss: 0.3038 - Train accuracy: 0.8944 --- Test loss: 0.4309 - Test accuracy: 0.8592
# Epoch: __ 54
# ... finished after 48.12 seconds --- Train loss: 0.294 - Train accuracy: 0.8961 --- Test loss: 0.4315 - Test accuracy: 0.8583
# Epoch: __ 55
# ... finished after 48.3 seconds --- Train loss: 0.319 - Train accuracy: 0.8867 --- Test loss: 0.4298 - Test accuracy: 0.8604
# Epoch: __ 56
# ... finished after 48.1 seconds --- Train loss: 0.2767 - Train accuracy: 0.8956 --- Test loss: 0.4248 - Test accuracy: 0.8595
# Epoch: __ 57
# ... finished after 48.02 seconds --- Train loss: 0.2612 - Train accuracy: 0.9059 --- Test loss: 0.4279 - Test accuracy: 0.8577
# Epoch: __ 58
# ... finished after 47.97 seconds --- Train loss: 0.2878 - Train accuracy: 0.9131 --- Test loss: 0.4173 - Test accuracy: 0.859
# Epoch: __ 59
# ... finished after 48.0 seconds --- Train loss: 0.2699 - Train accuracy: 0.9015 --- Test loss: 0.4274 - Test accuracy: 0.8632
# Epoch: __ 60
# ... finished after 47.61 seconds --- Train loss: 0.2949 - Train accuracy: 0.8963 --- Test loss: 0.4226 - Test accuracy: 0.8614
# Epoch: __ 61
# ... finished after 48.34 seconds --- Train loss: 0.2816 - Train accuracy: 0.9033 --- Test loss: 0.4155 - Test accuracy: 0.8652
# Epoch: __ 62
# ... finished after 48.08 seconds --- Train loss: 0.278 - Train accuracy: 0.9066 --- Test loss: 0.4361 - Test accuracy: 0.8606
# Epoch: __ 63
# ... finished after 48.39 seconds --- Train loss: 0.3025 - Train accuracy: 0.8943 --- Test loss: 0.4182 - Test accuracy: 0.8637
# Epoch: __ 64
# ... finished after 47.86 seconds --- Train loss: 0.222 - Train accuracy: 0.9242 --- Test loss: 0.4439 - Test accuracy: 0.8559
# Epoch: __ 65
# ... finished after 47.85 seconds --- Train loss: 0.2451 - Train accuracy: 0.9181 --- Test loss: 0.4298 - Test accuracy: 0.8639
# Epoch: __ 66
# ... finished after 48.02 seconds --- Train loss: 0.246 - Train accuracy: 0.9132 --- Test loss: 0.4537 - Test accuracy: 0.857
# Epoch: __ 67
# ... finished after 47.97 seconds --- Train loss: 0.2652 - Train accuracy: 0.9069 --- Test loss: 0.4309 - Test accuracy: 0.8622
# Epoch: __ 68
# ... finished after 48.04 seconds --- Train loss: 0.2604 - Train accuracy: 0.907 --- Test loss: 0.4549 - Test accuracy: 0.8535
# Epoch: __ 69
# ... finished after 48.17 seconds --- Train loss: 0.2232 - Train accuracy: 0.9174 --- Test loss: 0.4143 - Test accuracy: 0.865
# Epoch: __ 70
# ... finished after 48.19 seconds --- Train loss: 0.2383 - Train accuracy: 0.9162 --- Test loss: 0.4226 - Test accuracy: 0.8656
# Epoch: __ 71
# ... finished after 48.06 seconds --- Train loss: 0.2482 - Train accuracy: 0.9114 --- Test loss: 0.4264 - Test accuracy: 0.8668
# Epoch: __ 72
# ... finished after 47.94 seconds --- Train loss: 0.2258 - Train accuracy: 0.9202 --- Test loss: 0.452 - Test accuracy: 0.8591
# Epoch: __ 73
# ... finished after 48.26 seconds --- Train loss: 0.21 - Train accuracy: 0.9201 --- Test loss: 0.445 - Test accuracy: 0.8608
# Epoch: __ 74
# ... finished after 48.21 seconds --- Train loss: 0.2466 - Train accuracy: 0.9148 --- Test loss: 0.4388 - Test accuracy: 0.8609
# Epoch: __ 75
# ... finished after 48.42 seconds --- Train loss: 0.2339 - Train accuracy: 0.9253 --- Test loss: 0.4263 - Test accuracy: 0.8629
# Epoch: __ 76
# ... finished after 48.27 seconds --- Train loss: 0.2272 - Train accuracy: 0.9182 --- Test loss: 0.43 - Test accuracy: 0.863
# Epoch: __ 77
# ... finished after 48.31 seconds --- Train loss: 0.2358 - Train accuracy: 0.916 --- Test loss: 0.4171 - Test accuracy: 0.8646
# Epoch: __ 78
# ... finished after 48.01 seconds --- Train loss: 0.2535 - Train accuracy: 0.9184 --- Test loss: 0.4404 - Test accuracy: 0.8613
# Epoch: __ 79
# ... finished after 49.4 seconds --- Train loss: 0.2166 - Train accuracy: 0.9312 --- Test loss: 0.4453 - Test accuracy: 0.8609
# Epoch: __ 80
# ... finished after 48.14 seconds --- Train loss: 0.2472 - Train accuracy: 0.9121 --- Test loss: 0.4392 - Test accuracy: 0.8607
# Epoch: __ 81
# ... finished after 48.02 seconds --- Train loss: 0.201 - Train accuracy: 0.9263 --- Test loss: 0.4289 - Test accuracy: 0.8624
# Epoch: __ 82
# ... finished after 48.28 seconds --- Train loss: 0.2356 - Train accuracy: 0.9143 --- Test loss: 0.4477 - Test accuracy: 0.8581
# Epoch: __ 83
# ... finished after 48.18 seconds --- Train loss: 0.1988 - Train accuracy: 0.9318 --- Test loss: 0.4384 - Test accuracy: 0.8606
# Epoch: __ 84
# ... finished after 48.18 seconds --- Train loss: 0.2399 - Train accuracy: 0.9171 --- Test loss: 0.4331 - Test accuracy: 0.8643
# Epoch: __ 85
# ... finished after 48.06 seconds --- Train loss: 0.2104 - Train accuracy: 0.9252 --- Test loss: 0.4383 - Test accuracy: 0.8632
# Epoch: __ 86
# ... finished after 47.74 seconds --- Train loss: 0.2072 - Train accuracy: 0.9281 --- Test loss: 0.4332 - Test accuracy: 0.8604
# Epoch: __ 87
# ... finished after 48.35 seconds --- Train loss: 0.2103 - Train accuracy: 0.9276 --- Test loss: 0.4253 - Test accuracy: 0.8657
# Epoch: __ 88
# ... finished after 48.29 seconds --- Train loss: 0.1771 - Train accuracy: 0.9369 --- Test loss: 0.4444 - Test accuracy: 0.8603
# Epoch: __ 89
# ... finished after 48.28 seconds --- Train loss: 0.2612 - Train accuracy: 0.9126 --- Test loss: 0.4369 - Test accuracy: 0.8612
# Epoch: __ 90
# ... finished after 47.96 seconds --- Train loss: 0.208 - Train accuracy: 0.9304 --- Test loss: 0.4294 - Test accuracy: 0.8646
# Epoch: __ 91
# ... finished after 48.04 seconds --- Train loss: 0.192 - Train accuracy: 0.9291 --- Test loss: 0.4231 - Test accuracy: 0.8664
# Epoch: __ 92
# ... finished after 48.21 seconds --- Train loss: 0.2332 - Train accuracy: 0.9168 --- Test loss: 0.4393 - Test accuracy: 0.864
# Epoch: __ 93
# ... finished after 48.22 seconds --- Train loss: 0.189 - Train accuracy: 0.9343 --- Test loss: 0.4389 - Test accuracy: 0.8652
# Epoch: __ 94
# ... finished after 48.24 seconds --- Train loss: 0.1952 - Train accuracy: 0.935 --- Test loss: 0.4373 - Test accuracy: 0.8644
# Epoch: __ 95
# ... finished after 48.12 seconds --- Train loss: 0.1857 - Train accuracy: 0.9342 --- Test loss: 0.4255 - Test accuracy: 0.864
# Epoch: __ 96
# ... finished after 48.31 seconds --- Train loss: 0.2144 - Train accuracy: 0.9328 --- Test loss: 0.4365 - Test accuracy: 0.8611
# Epoch: __ 97
# ... finished after 48.19 seconds --- Train loss: 0.1939 - Train accuracy: 0.9297 --- Test loss: 0.4355 - Test accuracy: 0.8632
# Epoch: __ 98
# ... finished after 48.5 seconds --- Train loss: 0.1868 - Train accuracy: 0.9416 --- Test loss: 0.447 - Test accuracy: 0.8613
# Epoch: __ 99
# ... finished after 48.7 seconds --- Train loss: 0.1977 - Train accuracy: 0.9278 --- Test loss: 0.4477 - Test accuracy: 0.8617
# Epoch: __ 100
# ... finished after 48.59 seconds --- Train loss: 0.2047 - Train accuracy: 0.9325 --- Test loss: 0.4568 - Test accuracy: 0.8607

# %% [markdown]
# # Plot results

# %%
plt.figure(figsize=(20,5))
plt.plot(train_accuracies, label="train")
plt.plot(test_accuracies, label="test")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.figure(figsize=(20,5))
plt.plot(train_losses, label="train")
plt.plot(test_losses, label="test")
plt.legend()
plt.title("Loss")
plt.show()

# %% [markdown]
# # Check final accuracies
#
# If we take a look at the last 15 epochs we can see that minimum and maximum test accuracy are very similar. Also in the plot we can see that starting around epochs 60-70 the model starts overfitting slightly: The test accuracy remains at values around 86% while the training accuracy further increased. So, training for fewer epochs would have sufficed for our case.

# %%
print("mean:", np.mean(test_accuracies[-15:-1]))
print("min:", np.min(test_accuracies[-15:-1]))
print("max:", np.max(test_accuracies[-15:-1]))
# Out:
# mean: 0.8630880837912088
# min: 0.8602764423076923
# max: 0.866386217948718
